# %%
import numpy as np

# %%
import pandas as pd

# %%
#for reading data
data=pd.read_csv("astronauts.csv")

# %%
data
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# ...

# %%
#by this we can check how many missing values in this data sets
data.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %% [markdown]
# # How many missing data points do we have?

# %%
missing_values_count=data.isnull().sum()

# %%
missing_values_count
# Out:
# Name                     0
# Year                    27
# Group                   27
# Status                   0
# Birth Date               0
# Birth Place              0
# Gender                   0
# Alma Mater               1
# Undergraduate Major     22
# Graduate Major          59
# Military Rank          150
# Military Branch        146
# Space Flights            0
# Space Flight (hr)        0
# Space Walks              0
# Space Walks (hr)         0
# Missions                23
# Death Date             305
# Death Mission          341
# dtype: int64

# %%
missing_values_count[0:19]
# Out:
# Name                     0
# Year                    27
# Group                   27
# Status                   0
# Birth Date               0
# Birth Place              0
# Gender                   0
# Alma Mater               1
# Undergraduate Major     22
# Graduate Major          59
# Military Rank          150
# Military Branch        146
# Space Flights            0
# Space Flight (hr)        0
# Space Walks              0
# Space Walks (hr)         0
# Missions                23
# Death Date             305
# Death Mission          341
# dtype: int64

# %%
total_cells=np.product(data.shape)

# %%
total_cells
# Out:
# 6783

# %%
totall_missing=missing_values_count.sum()

# %%
percent_missing=(totall_missing/total_cells)*100

# %%
percent_missing
# Out:
# 16.231755860238835

# %%
missing_values_count[0:10]
# Out:
# Name                    0
# Year                   27
# Group                  27
# Status                  0
# Birth Date              0
# Birth Place             0
# Gender                  0
# Alma Mater              1
# Undergraduate Major    22
# Graduate Major         59
# dtype: int64

# %%
#remove all the rows that contain a missing value
data.dropna()
# Out:
#                     Name    Year  Group    Status  Birth Date  \
# 10   Michael P. Anderson  1995.0   15.0  Deceased  12/25/1959
# 42        David M. Brown  1996.0   16.0  Deceased   4/16/1956
# 70       Laurel B. Clark  1996.0   16.0  Deceased   3/10/1961
# 170      Rick D. Husband  1995.0   15.0  Deceased   7/12/1957
# 222    William C. McCool  1996.0   16.0  Deceased   9/23/1961
# 250   Ellison S. Onizuka  1978.0    8.0  Deceased   6/24/1946
# 301     Michael J. Smith  1980.0    9.0  Deceased   4/30/1945
#
#          Birth Place  Gender  \
# 10   Plattsburgh, NY    Male
# 42     Arlington, VA    Male
# 70          Ames, IA  Female
# 170     Amarillo, TX    Male
# 222    San Diego, CA    Male
# 250   Kealakekua, HI    Male
# 301     Beaufort, NC    Male
#
#                                             Alma Mater  \
# 10      University of Washington; Creighton University
# 42   College of William & Mary; Eastern Virginia Me...
# ...

# %%
col_with_na_drop=data.dropna(axis=1)

# %%
col_with_na_drop.head()
# Out:
#                Name   Status Birth Date    Birth Place Gender  Space Flights  \
# 0   Joseph M. Acaba   Active  5/17/1967  Inglewood, CA   Male              2
# 1    Loren W. Acton  Retired   3/7/1936   Lewiston, MT   Male              1
# 2  James C. Adamson  Retired   3/3/1946     Warsaw, NY   Male              2
# 3   Thomas D. Akers  Retired  5/20/1951  St. Louis, MO   Male              4
# 4       Buzz Aldrin  Retired  1/20/1930  Montclair, NJ   Male              2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)
# 0               3307            2              13.0
# 1                190            0               0.0
# 2                334            0               0.0
# 3                814            4              29.0
# 4                289            2               8.0

# %%
print("Columns in original dataset: %d \n" % data.shape[1])
print("Columns with na's dropped: %d" % col_with_na_drop.shape[1])
# Out:
# Columns in original dataset: 19
#
# Columns with na's dropped: 9

# %%
# Out:
#   File "C:\Users\Leo\AppData\Local\Temp/ipykernel_13780/944902170.py", line 3
#     plt.pie(Missions_counts.values, labels=Missions_counts.index, autopct='%1.1f%
#                                                                                  ^
# SyntaxError: EOL while scanning string literal
